# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
#BATCH_SIZE = 20
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
#EPOCHS = 15
EPOCHS = 25
#EPOCHS = 30
print(ROOT_PATH)
# Out:
# /home/aiffel0042/aiffel

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1063
# Pneumonia images count in training set: 3122

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.97
# Weight for class 1: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.3708 - accuracy: 0.8132 - precision: 0.9558 - recall: 0.7857 - val_loss: 0.7743 - val_accuracy: 0.7269 - val_precision: 0.7269 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.2351 - accuracy: 0.9114 - precision: 0.9751 - recall: 0.9045 - val_loss: 1.4797 - val_accuracy: 0.7269 - val_precision: 0.7269 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.2249 - accuracy: 0.9203 - precision: 0.9750 - recall: 0.9164 - val_loss: 0.3076 - val_accuracy: 0.8298 - val_precision: 0.8108 - val_recall: 0.9987
# Epoch 4/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1912 - accuracy: 0.9253 - precision: 0.9779 - recall: 0.9209 - val_loss: 0.1556 - val_accuracy: 0.9413 - val_precision: 0.9273 - val_recall: 0.9973
# Epoch 5/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1503 - accuracy: 0.9437 - precision: 0.9842 - recall: 0.9395 - val_loss: 0.7839 - val_accuracy: 0.7885 - val_precision: 1.0000 - val_recall: 0.7094
# Epoch 6/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1596 - accuracy: 0.9399 - precision: 0.9792 - recall: 0.9392 - val_loss: 0.2266 - val_accuracy: 0.9019 - val_precision: 0.8876 - val_recall: 0.9908
# Epoch 7/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1390 - accuracy: 0.9440 - precision: 0.9846 - recall: 0.9398 - val_loss: 0.1501 - val_accuracy: 0.9519 - val_precision: 0.9413 - val_recall: 0.9960
# Epoch 8/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1456 - accuracy: 0.9452 - precision: 0.9813 - recall: 0.9444 - val_loss: 0.1017 - val_accuracy: 0.9577 - val_precision: 0.9917 - val_recall: 0.9499
# Epoch 9/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1171 - accuracy: 0.9555 - precision: 0.9880 - recall: 0.9519 - val_loss: 0.0978 - val_accuracy: 0.9654 - val_precision: 0.9639 - val_recall: 0.9894
# Epoch 10/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1101 - accuracy: 0.9574 - precision: 0.9877 - recall: 0.9547 - val_loss: 0.0791 - val_accuracy: 0.9692 - val_precision: 0.9653 - val_recall: 0.9934
# Epoch 11/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1242 - accuracy: 0.9528 - precision: 0.9877 - recall: 0.9487 - val_loss: 0.0781 - val_accuracy: 0.9702 - val_precision: 0.9788 - val_recall: 0.9801
# Epoch 12/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1099 - accuracy: 0.9583 - precision: 0.9900 - recall: 0.9538 - val_loss: 0.0744 - val_accuracy: 0.9788 - val_precision: 0.9829 - val_recall: 0.9881
# Epoch 13/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1145 - accuracy: 0.9583 - precision: 0.9897 - recall: 0.9541 - val_loss: 0.0992 - val_accuracy: 0.9663 - val_precision: 0.9640 - val_recall: 0.9907
# Epoch 14/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.0896 - accuracy: 0.9665 - precision: 0.9908 - recall: 0.9641 - val_loss: 0.1543 - val_accuracy: 0.9423 - val_precision: 1.0000 - val_recall: 0.9206
# Epoch 15/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.0995 - accuracy: 0.9614 - precision: 0.9901 - recall: 0.9580 - val_loss: 0.0876 - val_accuracy: 0.9712 - val_precision: 0.9629 - val_recall: 0.9987
# Epoch 16/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0883 - accuracy: 0.9646 - precision: 0.9914 - recall: 0.9608 - val_loss: 0.0578 - val_accuracy: 0.9798 - val_precision: 0.9906 - val_recall: 0.9814
# Epoch 17/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0866 - accuracy: 0.9674 - precision: 0.9934 - recall: 0.9627 - val_loss: 0.2387 - val_accuracy: 0.9288 - val_precision: 0.9117 - val_recall: 0.9987
# Epoch 18/25
# 261/261 [==============================] - 21s 82ms/step - loss: 0.1251 - accuracy: 0.9528 - precision: 0.9883 - recall: 0.9480 - val_loss: 0.1813 - val_accuracy: 0.9250 - val_precision: 0.9985 - val_recall: 0.8983
# Epoch 19/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0828 - accuracy: 0.9648 - precision: 0.9944 - recall: 0.9585 - val_loss: 0.0548 - val_accuracy: 0.9769 - val_precision: 0.9919 - val_recall: 0.9762
# Epoch 20/25
# 261/261 [==============================] - 22s 82ms/step - loss: 0.0720 - accuracy: 0.9715 - precision: 0.9931 - recall: 0.9684 - val_loss: 0.0810 - val_accuracy: 0.9712 - val_precision: 0.9801 - val_recall: 0.9801
# Epoch 21/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0721 - accuracy: 0.9741 - precision: 0.9937 - recall: 0.9713 - val_loss: 0.0752 - val_accuracy: 0.9692 - val_precision: 0.9905 - val_recall: 0.9668
# Epoch 22/25
# 261/261 [==============================] - 22s 82ms/step - loss: 0.0829 - accuracy: 0.9674 - precision: 0.9927 - recall: 0.9634 - val_loss: 0.0728 - val_accuracy: 0.9750 - val_precision: 0.9790 - val_recall: 0.9868
# Epoch 23/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0733 - accuracy: 0.9749 - precision: 0.9951 - recall: 0.9713 - val_loss: 0.0627 - val_accuracy: 0.9808 - val_precision: 0.9933 - val_recall: 0.9801
# Epoch 24/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0740 - accuracy: 0.9753 - precision: 0.9947 - recall: 0.9721 - val_loss: 0.0785 - val_accuracy: 0.9692 - val_precision: 0.9973 - val_recall: 0.9604
# Epoch 25/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0683 - accuracy: 0.9761 - precision: 0.9941 - recall: 0.9737 - val_loss: 0.1480 - val_accuracy: 0.9683 - val_precision: 0.9865 - val_recall: 0.9696

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 55ms/step - loss: 1.0515 - accuracy: 0.8333 - precision: 0.7979 - recall: 0.9821

# %% [markdown]
#   ## augumet 수행하면 오히려 정확도 떨어짐
#   ## accuracy: 0.7596
#
#
#
# def augment(image,label):
#     image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
#     return image,label
#
# def prepare_for_training(ds, shuffle_buffer_size=1000):
#     # augment 적용 부분이 배치처리 함수에 추가되었습니다.
#     ds = ds.map(
#             augment,       # augment 함수 적용
#             num_parallel_calls=2
#         )
#
#     ds = ds.shuffle(buffer_size=shuffle_buffer_size)
#
#     ds = ds.repeat()
#
#     ds = ds.batch(BATCH_SIZE)
#
#     ds = ds.prefetch(buffer_size=AUTOTUNE)
#
#     return ds
#
# train_ds = prepare_for_training(train_ds)
# val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### augument 진행시 오히려 낮은 정확도
# ![스크린샷, 2020-10-27 13-10-33.png](attachment:스크린샷, 2020-10-27 13-10-33.png)
# file:///home/aiffel0042/%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7,%202020-10-27%2013-10-33.png![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
