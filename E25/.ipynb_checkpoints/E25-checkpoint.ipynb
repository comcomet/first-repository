# %%
import numpy as np
import matplotlib.pyplot as plt

def single_tone(frequecy, sampling_rate=16000, duration=1):
    t = np.linspace(0, duration, int(sampling_rate))
    y = np.sin(2 * np.pi * frequecy * t)
    return y

y = single_tone(400)

# %%
plt.plot(y[:41])
plt.show()

# %%
plt.stem(y[:41])
plt.show()
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np
import os

data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)

print("✅")
# Out:
# ✅

# %%
print("Wave data shape : ", speech_data["wav_vals"].shape)
print("Label data shape : ", speech_data["label_vals"].shape)
print("✅")
# Out:
# Wave data shape :  (50620, 8000)
# Label data shape :  (50620, 1)
# ✅

# %%
import IPython.display as ipd
import random

# 데이터 선택
rand = random.randint(0, len(speech_data["wav_vals"]))
print("rand num : ", rand)

sr = 8000 # 1초동안 재생되는 샘플의 갯수
data = speech_data["wav_vals"][rand]
print("Wave data shape : ", data.shape)
print("label : ", speech_data["label_vals"][rand])

ipd.Audio(data, rate=sr)
# Out:
# rand num :  46847
# Wave data shape :  (8000,)
# label :  ['silence']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value
print("✅")
# Out:
# ✅

# %%
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)
print("✅")
# Out:
# ✅

# %%
from sklearn.model_selection import train_test_split

sr = 8000
train_wav, test_wav, train_label, test_label = train_test_split(speech_data["wav_vals"], 
                                                                label_data, 
                                                                test_size=0.1,
                                                                shuffle=True)
print(train_wav)

train_wav = train_wav.reshape([-1, sr, 1]) # add channel for CNN
test_wav = test_wav.reshape([-1, sr, 1])
print("✅")
# Out:
# [[ 3.2623836e-03  4.6461741e-03  1.4220466e-05 ...  2.6386776e-03
#    2.0477506e-03 -1.7893560e-03]
#  [ 4.9907867e-05  1.1650613e-04 -4.7367474e-05 ...  8.9958405e-05
#    5.1495197e-05  6.2451021e-05]
#  [ 3.0129012e-03  2.4242231e-03 -1.5838990e-03 ...  2.1205409e-03
#    2.6851341e-03 -9.8139863e-05]
#  ...
#  [-1.6284229e-02  6.0398346e-03  7.0986926e-04 ... -2.7183792e-02
#    1.0466146e-02  1.0039617e-02]
#  [ 6.6341113e-06 -8.0808117e-05  2.0807202e-04 ...  4.6707725e-04
#    2.3030832e-04 -6.9595559e-04]
#  [ 4.5762905e-03  7.2609074e-03  2.7723438e-03 ...  4.4048503e-03
#    3.9520347e-03  2.9654976e-04]]
# ✅

# %%
print("train data : ", train_wav.shape)
print("train labels : ", train_label.shape)
print("test data : ", test_wav.shape)
print("test labels : ", test_label.shape)
print("✅")
# Out:
# train data :  (45558, 8000, 1)
# train labels :  (45558,)
# test data :  (5062, 8000, 1)
# test labels :  (5062,)
# ✅

# %%
batch_size = 16
max_epochs = 10

# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/wav'

checkpoint_dir
# Out:
# '/home/aiffel0042/aiffel/speech_recognition/models/wav'

# %%
def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    return wav, label
print("✅")
# Out:
# ✅

# %%
import tensorflow as tf

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)
print("✅")
# Out:
# <BatchDataset shapes: ((None, 8000, 1), (None, 12)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 8000, 1), (None, 12)), types: (tf.float32, tf.float32)>
# ✅

# %%
from tensorflow.keras import layers

input_tensor = layers.Input(shape=(sr, 1))

x = layers.Conv1D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv1D(32, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav = tf.keras.Model(input_tensor, output_tensor)

model_wav.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 8000, 32)          320
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 8000, 32)          9248
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 4000, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4000, 64)          18496
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 4000, 64)          36928
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 2000, 64)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 2000, 128)         73856
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2000, 128)         147584
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 2000, 128)         147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1000, 128)         0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1000, 256)         295168
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1000, 256)         590080
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1000, 256)         590080
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 500, 256)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 500, 256)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128000)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               32768256
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 34,681,708
# Trainable params: 34,681,196
# Non-trainable params: 512
# _________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
print("✅")
# Out:
# ✅

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
print("✅")
# Out:
# ✅

# %%
#30분 내외 소요
history_wav = model_wav.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
print("✅")
# Out:
# Epoch 1/10
#   2/355 [..............................] - ETA: 1:09 - loss: 2.4684 - accuracy: 0.0898WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1299s vs `on_train_batch_end` time: 0.2642s). Check your callbacks.
# 355/355 [==============================] - ETA: 0s - loss: 1.5610 - accuracy: 0.4757
# Epoch 00001: val_loss improved from inf to 1.32813, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 138s 389ms/step - loss: 1.5610 - accuracy: 0.4757 - val_loss: 1.3281 - val_accuracy: 0.5839
# Epoch 2/10
# 355/355 [==============================] - ETA: 0s - loss: 0.8751 - accuracy: 0.7341
# Epoch 00002: val_loss improved from 1.32813 to 0.79717, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 139s 391ms/step - loss: 0.8751 - accuracy: 0.7341 - val_loss: 0.7972 - val_accuracy: 0.7456
# Epoch 3/10
# 355/355 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.8088
# Epoch 00003: val_loss improved from 0.79717 to 0.60937, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 137s 387ms/step - loss: 0.6475 - accuracy: 0.8088 - val_loss: 0.6094 - val_accuracy: 0.8079
# Epoch 4/10
# 355/355 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.8647
# Epoch 00004: val_loss improved from 0.60937 to 0.52849, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 134s 378ms/step - loss: 0.4792 - accuracy: 0.8647 - val_loss: 0.5285 - val_accuracy: 0.8381
# Epoch 5/10
# 355/355 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.9019
# Epoch 00005: val_loss did not improve from 0.52849
# 355/355 [==============================] - 138s 389ms/step - loss: 0.3657 - accuracy: 0.9019 - val_loss: 0.6270 - val_accuracy: 0.8073
# Epoch 6/10
# 355/355 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9266
# Epoch 00006: val_loss improved from 0.52849 to 0.40255, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 139s 392ms/step - loss: 0.2867 - accuracy: 0.9266 - val_loss: 0.4026 - val_accuracy: 0.8752
# Epoch 7/10
# 355/355 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9478
# Epoch 00007: val_loss did not improve from 0.40255
# 355/355 [==============================] - 138s 390ms/step - loss: 0.2161 - accuracy: 0.9478 - val_loss: 0.4551 - val_accuracy: 0.8506
# Epoch 8/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9622
# Epoch 00008: val_loss improved from 0.40255 to 0.35766, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 139s 392ms/step - loss: 0.1698 - accuracy: 0.9622 - val_loss: 0.3577 - val_accuracy: 0.8874
# Epoch 9/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9707
# Epoch 00009: val_loss improved from 0.35766 to 0.32040, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 139s 391ms/step - loss: 0.1390 - accuracy: 0.9707 - val_loss: 0.3204 - val_accuracy: 0.9036
# Epoch 10/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9779
# Epoch 00010: val_loss improved from 0.32040 to 0.30186, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav
# 355/355 [==============================] - 139s 391ms/step - loss: 0.1096 - accuracy: 0.9779 - val_loss: 0.3019 - val_accuracy: 0.9077
# ✅

# %%
import matplotlib.pyplot as plt

acc = history_wav.history['accuracy']
val_acc = history_wav.history['val_accuracy']

loss=history_wav.history['loss']
val_loss=history_wav.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")
# Out:
# ✅

# %%
model_wav.load_weights(checkpoint_dir)
print("✅")
# Out:
# ✅

# %%
results = model_wav.evaluate(test_dataset)
print("✅")
# Out:
# 40/40 [==============================] - 7s 180ms/step - loss: 0.3002 - accuracy: 0.9083
# ✅

# %%
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
# Out:
# loss value: 0.300
# accuracy value: 90.8337%
# ✅

# %%
inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_wav), size=1, replace=False)

batch_xs = test_wav[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = model_wav(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))

ipd.Audio(batch_xs.reshape(8000,), rate=8000)
# Out:
# label :  stop
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
if np.argmax(y_pred_) == test_label[i]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]))
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]))
print("✅")
# Out:
# y_pred: stop
# ✅

# %%
input_tensor = layers.Input(shape=(sr, 1))

x = layers.Conv1D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv1D(32, 9, padding='same', activation='relu')(x)
skip_1 = layers.MaxPool1D()(x)

x = layers.Conv1D(64, 9, padding='same', activation='relu')(skip_1)
x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_1], -1)
skip_2 = layers.MaxPool1D()(x)

x = layers.Conv1D(128, 9, padding='same', activation='relu')(skip_2)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_2], -1)
skip_3 = layers.MaxPool1D()(x)

x = layers.Conv1D(256, 9, padding='same', activation='relu')(skip_3)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_3], -1)
x = layers.MaxPool1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav_skip = tf.keras.Model(input_tensor, output_tensor)

model_wav_skip.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 8000, 32)     320         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 8000, 32)     9248        conv1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 4000, 32)     0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 4000, 64)     18496       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 4000, 64)     36928       conv1d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 4000, 96)]   0           conv1d_13[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 2000, 96)     0           tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 2000, 128)    110720      max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 2000, 128)    147584      conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 2000, 128)    147584      conv1d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 2000, 224)]  0           conv1d_16[0][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 1000, 224)    0           tf_op_layer_concat_1[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1000, 256)    516352      max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1000, 256)    590080      conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1000, 256)    590080      conv1d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 1000, 480)]  0           conv1d_19[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 500, 480)     0           tf_op_layer_concat_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 500, 480)     0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 240000)       0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          61440256    flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 12)           3084        activation_1[0][0]
# ==================================================================================================
# Total params: 63,611,756
# Trainable params: 63,611,244
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav_skip.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
print("✅")
# Out:
# ✅

# %%
# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/wav_skip'

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
print("✅")
# Out:
# ✅

# %%
#30분 내외 소요
history_wav_skip = model_wav_skip.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
print("✅")
# Out:
# Epoch 1/10
#   2/355 [..............................] - ETA: 1:31 - loss: 2.7982 - accuracy: 0.0977WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1356s vs `on_train_batch_end` time: 0.3056s). Check your callbacks.
# 355/355 [==============================] - ETA: 0s - loss: 1.4130 - accuracy: 0.5468
# Epoch 00001: val_loss improved from inf to 1.29917, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 162s 457ms/step - loss: 1.4130 - accuracy: 0.5468 - val_loss: 1.2992 - val_accuracy: 0.5855
# Epoch 2/10
# 355/355 [==============================] - ETA: 0s - loss: 0.7611 - accuracy: 0.7783
# Epoch 00002: val_loss improved from 1.29917 to 0.67312, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 163s 459ms/step - loss: 0.7611 - accuracy: 0.7783 - val_loss: 0.6731 - val_accuracy: 0.7983
# Epoch 3/10
# 355/355 [==============================] - ETA: 0s - loss: 0.5227 - accuracy: 0.8590
# Epoch 00003: val_loss improved from 0.67312 to 0.55718, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 164s 461ms/step - loss: 0.5227 - accuracy: 0.8590 - val_loss: 0.5572 - val_accuracy: 0.8271
# Epoch 4/10
# 355/355 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.9144
# Epoch 00004: val_loss improved from 0.55718 to 0.43059, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 163s 460ms/step - loss: 0.3528 - accuracy: 0.9144 - val_loss: 0.4306 - val_accuracy: 0.8688
# Epoch 5/10
# 355/355 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9472
# Epoch 00005: val_loss improved from 0.43059 to 0.39964, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 163s 461ms/step - loss: 0.2403 - accuracy: 0.9472 - val_loss: 0.3996 - val_accuracy: 0.8748
# Epoch 6/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9649
# Epoch 00006: val_loss improved from 0.39964 to 0.33411, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 163s 458ms/step - loss: 0.1688 - accuracy: 0.9649 - val_loss: 0.3341 - val_accuracy: 0.8940
# Epoch 7/10
# 355/355 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9753
# Epoch 00007: val_loss improved from 0.33411 to 0.26158, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 163s 459ms/step - loss: 0.1261 - accuracy: 0.9753 - val_loss: 0.2616 - val_accuracy: 0.9243
# Epoch 8/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9819
# Epoch 00008: val_loss did not improve from 0.26158
# 355/355 [==============================] - 155s 436ms/step - loss: 0.0932 - accuracy: 0.9819 - val_loss: 0.2896 - val_accuracy: 0.9187
# Epoch 9/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9856
# Epoch 00009: val_loss did not improve from 0.26158
# 355/355 [==============================] - 161s 452ms/step - loss: 0.0733 - accuracy: 0.9856 - val_loss: 0.2922 - val_accuracy: 0.9165
# Epoch 10/10
# 355/355 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9880
# Epoch 00010: val_loss improved from 0.26158 to 0.24325, saving model to /home/aiffel0042/aiffel/speech_recognition/models/wav_skip
# 355/355 [==============================] - 163s 460ms/step - loss: 0.0612 - accuracy: 0.9880 - val_loss: 0.2433 - val_accuracy: 0.9321
# ✅

# %%
import matplotlib.pyplot as plt

acc = history_wav_skip.history['accuracy']
val_acc = history_wav_skip.history['val_accuracy']

loss=history_wav_skip.history['loss']
val_loss=history_wav_skip.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")
# Out:
# ✅

# %%
# Evaluation 

model_wav_skip.load_weights(checkpoint_dir)
results = model_wav_skip.evaluate(test_dataset)

# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
# Out:
# 40/40 [==============================] - 6s 143ms/step - loss: 0.2418 - accuracy: 0.9322
# loss value: 0.242
# accuracy value: 93.2240%
# ✅

# %%
# Test 

inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_wav), size=1, replace=False)

batch_xs = test_wav[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = model_wav_skip(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))

ipd.Audio(batch_xs.reshape(8000,), rate=8000)
# Out:
# label :  go
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
if np.argmax(y_pred_) == test_label[i]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]))
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]))
print("✅")
# Out:
# y_pred: go
# ✅

# %%
import librosa

def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D
print("✅")
# Out:
# ✅

# %%
# 위에서 뽑았던 sample data
spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)
# Out:
# Waveform shape :  (8000,)
# Spectrogram shape :  (130, 126)

# %%
import librosa.display

librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 프로젝트
# (2차원)

# %%
data = speech_data['wav_vals']

# %%
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)
print("✅")
# Out:
# ✅

# %%
spec_data = []

for w in speech_data["wav_vals"]:
    spec_data.append(wav2spec(w))
    
spec_data = np.array(spec_data)

# %%
train_wav, test_wav, train_label, test_label = train_test_split(spec_data, 
                                                                label_data, 
                                                                test_size=0.1,
                                                                shuffle=True)

# %%
# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)

# %%
input_tensor = layers.Input(shape=(130, 126, 1))

x = layers.Conv2D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv2D(32, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav = tf.keras.Model(input_tensor, output_tensor)

# %%
model_wav.summary()

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
print("✅")

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
print("✅")

# %%
# 30분 내외 소요
history_wav = model_wav.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
print("✅")

# %%
acc = history_wav.history['accuracy']
val_acc = history_wav.history['val_accuracy']

loss=history_wav.history['loss']
val_loss=history_wav.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")

# %%
model_wav.load_weights(checkpoint_dir)

# %%
results = model_wav.evaluate(test_dataset)

# %%
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
