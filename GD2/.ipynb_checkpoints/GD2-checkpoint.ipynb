# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'id': Text(shape=(), dtype=tf.string),
#     'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(50000, shape=(), dtype=int64)
# tf.Tensor(10000, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_info.features["label"].num_classes
# Out:
# 10

# %%
ds_info.features["label"].names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
# function for building VGG Block

def build_vgg_block(input_layer,
                    num_cnn=3, 
                    channel=64,
                    block_num=1,
                   ):
    # 입력 레이어
    x = input_layer

    # CNN 레이어
    for cnn_num in range(num_cnn):
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(3,3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_conv{cnn_num}'
        )(x)    

    # Max Pooling 레이어
    x = keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=2,
        name=f'block{block_num}_pooling'
    )(x)

    return x

# %%
vgg_input_layer = keras.layers.Input(shape=(32,32,3))   # 입력 레이어 생성
vgg_block_output = build_vgg_block(vgg_input_layer)    # VGG 블록 생성

# %%
# 블록 1개짜리 model 생성
model = keras.Model(inputs=vgg_input_layer, outputs=vgg_block_output)  

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 16, 16, 64)        0
# =================================================================
# Total params: 75,648
# Trainable params: 75,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG 모델 자체를 생성하는 함수입니다.
def build_vgg(input_shape=(32,32,3),
              num_cnn_list=[2,2,3,3,3],
              channel_list=[64,128,256,512,512],
              num_classes=10):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer
    
    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_vgg_block(
            output,
            num_cnn=num_cnn, 
            channel=channel,
            block_num=i
        )
        
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(4096, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(4096, activation='relu', name='fc2')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
# 기본값을 그대로 사용해서 VGG 모델을 만들면 VGG-16이 됩니다.
vgg_16 = build_vgg()

vgg_16.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 원하는 블록의 설계에 따라 매개변수로 리스트를 전달해 줍니다.
vgg_19 = build_vgg(
    num_cnn_list=[2,2,4,4,4],
    channel_list=[64,128,256,512,512]
)

vgg_19.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 38,947,914
# Trainable params: 38,947,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 256
EPOCH = 20

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
vgg_16.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_16 = vgg_16.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
#   2/195 [..............................] - ETA: 9s - loss: 2.3068 - accuracy: 0.1094WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0293s vs `on_train_batch_end` time: 0.0698s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0293s vs `on_train_batch_end` time: 0.0698s). Check your callbacks.
# 195/195 [==============================] - 32s 163ms/step - loss: 2.2000 - accuracy: 0.1884 - val_loss: 2.0770 - val_accuracy: 0.2534
# Epoch 2/20
# 195/195 [==============================] - 17s 89ms/step - loss: 2.0040 - accuracy: 0.2718 - val_loss: 1.9439 - val_accuracy: 0.2891
# Epoch 3/20
# 195/195 [==============================] - 18s 90ms/step - loss: 1.8773 - accuracy: 0.3225 - val_loss: 1.8140 - val_accuracy: 0.3544
# Epoch 4/20
# 195/195 [==============================] - 18s 91ms/step - loss: 1.7667 - accuracy: 0.3654 - val_loss: 1.7239 - val_accuracy: 0.3861
# Epoch 5/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.6797 - accuracy: 0.3973 - val_loss: 1.6262 - val_accuracy: 0.4117
# Epoch 6/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.6089 - accuracy: 0.4186 - val_loss: 1.5427 - val_accuracy: 0.4443
# Epoch 7/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.5581 - accuracy: 0.4404 - val_loss: 1.4914 - val_accuracy: 0.4677
# Epoch 8/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.5075 - accuracy: 0.4569 - val_loss: 1.4755 - val_accuracy: 0.4698
# Epoch 9/20
# 195/195 [==============================] - 18s 90ms/step - loss: 1.4621 - accuracy: 0.4751 - val_loss: 1.4513 - val_accuracy: 0.4785
# Epoch 10/20
# 195/195 [==============================] - 18s 90ms/step - loss: 1.4220 - accuracy: 0.4892 - val_loss: 1.4195 - val_accuracy: 0.4983
# Epoch 11/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.3804 - accuracy: 0.5055 - val_loss: 1.3603 - val_accuracy: 0.5080
# Epoch 12/20
# 195/195 [==============================] - 18s 91ms/step - loss: 1.3473 - accuracy: 0.5180 - val_loss: 1.3542 - val_accuracy: 0.5168
# Epoch 13/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.3078 - accuracy: 0.5318 - val_loss: 1.3070 - val_accuracy: 0.5406
# Epoch 14/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.2724 - accuracy: 0.5466 - val_loss: 1.2876 - val_accuracy: 0.5453
# Epoch 15/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.2331 - accuracy: 0.5624 - val_loss: 1.2624 - val_accuracy: 0.5486
# Epoch 16/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.2054 - accuracy: 0.5708 - val_loss: 1.1842 - val_accuracy: 0.5839
# Epoch 17/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.1807 - accuracy: 0.5803 - val_loss: 1.1548 - val_accuracy: 0.5938
# Epoch 18/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.1381 - accuracy: 0.5975 - val_loss: 1.1737 - val_accuracy: 0.5792
# Epoch 19/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.1128 - accuracy: 0.6059 - val_loss: 1.1695 - val_accuracy: 0.5832
# Epoch 20/20
# 195/195 [==============================] - 17s 89ms/step - loss: 1.0801 - accuracy: 0.6166 - val_loss: 1.1054 - val_accuracy: 0.6068

# %%
vgg_19.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_19 = vgg_19.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
#   2/195 [..............................] - ETA: 18s - loss: 2.3040 - accuracy: 0.1016WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0330s vs `on_train_batch_end` time: 0.0729s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0330s vs `on_train_batch_end` time: 0.0729s). Check your callbacks.
# 195/195 [==============================] - 21s 106ms/step - loss: 2.2288 - accuracy: 0.1747 - val_loss: 2.1324 - val_accuracy: 0.2163
# Epoch 2/20
# 195/195 [==============================] - 21s 106ms/step - loss: 2.0472 - accuracy: 0.2477 - val_loss: 1.9608 - val_accuracy: 0.2834
# Epoch 3/20
# 195/195 [==============================] - 21s 105ms/step - loss: 1.9054 - accuracy: 0.3071 - val_loss: 1.8139 - val_accuracy: 0.3492
# Epoch 4/20
# 195/195 [==============================] - 21s 105ms/step - loss: 1.7796 - accuracy: 0.3524 - val_loss: 1.7266 - val_accuracy: 0.3644
# Epoch 5/20
# 195/195 [==============================] - 21s 106ms/step - loss: 1.6912 - accuracy: 0.3910 - val_loss: 1.6439 - val_accuracy: 0.4115
# Epoch 6/20
# 195/195 [==============================] - 21s 108ms/step - loss: 1.6240 - accuracy: 0.4097 - val_loss: 1.6024 - val_accuracy: 0.4251
# Epoch 7/20
# 195/195 [==============================] - 21s 108ms/step - loss: 1.5705 - accuracy: 0.4330 - val_loss: 1.5680 - val_accuracy: 0.4138
# Epoch 8/20
# 195/195 [==============================] - 21s 108ms/step - loss: 1.5225 - accuracy: 0.4461 - val_loss: 1.5083 - val_accuracy: 0.4418
# Epoch 9/20
# 195/195 [==============================] - 21s 108ms/step - loss: 1.4760 - accuracy: 0.4675 - val_loss: 1.4512 - val_accuracy: 0.4649
# Epoch 10/20
# 195/195 [==============================] - 22s 111ms/step - loss: 1.4323 - accuracy: 0.4839 - val_loss: 1.4291 - val_accuracy: 0.4925
# Epoch 11/20
# 195/195 [==============================] - 22s 115ms/step - loss: 1.3832 - accuracy: 0.5034 - val_loss: 1.3757 - val_accuracy: 0.5040
# Epoch 12/20
# 195/195 [==============================] - 21s 106ms/step - loss: 1.3493 - accuracy: 0.5131 - val_loss: 1.3734 - val_accuracy: 0.5106
# Epoch 13/20
# 195/195 [==============================] - 21s 107ms/step - loss: 1.3156 - accuracy: 0.5279 - val_loss: 1.3061 - val_accuracy: 0.5433
# Epoch 14/20
# 195/195 [==============================] - 21s 107ms/step - loss: 1.2747 - accuracy: 0.5444 - val_loss: 1.2719 - val_accuracy: 0.5360
# Epoch 15/20
# 195/195 [==============================] - 21s 106ms/step - loss: 1.2392 - accuracy: 0.5575 - val_loss: 1.2463 - val_accuracy: 0.5612
# Epoch 16/20
# 195/195 [==============================] - 21s 106ms/step - loss: 1.2040 - accuracy: 0.5718 - val_loss: 1.2977 - val_accuracy: 0.5234
# Epoch 17/20
# 195/195 [==============================] - 21s 106ms/step - loss: 1.1742 - accuracy: 0.5833 - val_loss: 1.2272 - val_accuracy: 0.5584
# Epoch 18/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.1385 - accuracy: 0.5953 - val_loss: 1.1617 - val_accuracy: 0.5902
# Epoch 19/20
# 195/195 [==============================] - 20s 105ms/step - loss: 1.1147 - accuracy: 0.6027 - val_loss: 1.1827 - val_accuracy: 0.5744
# Epoch 20/20
# 195/195 [==============================] - 21s 109ms/step - loss: 1.0800 - accuracy: 0.6181 - val_loss: 1.1467 - val_accuracy: 0.5962

# %%
import matplotlib.pyplot as plt

plt.plot(history_16.history['loss'], 'r')
plt.plot(history_19.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()

# %%
plt.plot(history_16.history['val_accuracy'], 'r')
plt.plot(history_19.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()
