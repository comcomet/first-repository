# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/util/structure.py in normalize_element(element)
#      92       try:
# ---> 93         spec = type_spec_from_value(t, use_fallback=False)
#      94       except TypeError:
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/util/structure.py in type_spec_from_value(element, use_fallback)
#     465   raise TypeError("Could not build a TypeSpec for %r with type %s" %
# --> 466                   (element, type(element).__name__))
#     467
#
# TypeError: Could not build a TypeSpec for ['/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00000-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00001-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00002-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00003-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00004-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00005-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00006-of-00008', '/home/aiffel0042/tensorflow_datasets/cats_vs_dogs/4.0.0/cats_vs_dogs-train.tfrecord-00007-of-00008'] with type list
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-3-6c27afe85bb6> in <module>
#       8     split=['train', 'test'],
#       9     shuffle_files=True,
# ---> 10     with_info=True,
#      11 )
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      67     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      68     _check_required(fn, kwargs)
# ---> 69     return fn(*args, **kwargs)
#      70
#      71   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/registered.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     381   as_dataset_kwargs.setdefault("read_config", read_config)
#     382
# --> 383   ds = dbuilder.as_dataset(**as_dataset_kwargs)
#     384   if with_info:
#     385     return ds, dbuilder.info
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      67     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      68     _check_required(fn, kwargs)
# ---> 69     return fn(*args, **kwargs)
#      70
#      71   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_builder.py in as_dataset(self, split, batch_size, shuffle_files, decoders, read_config, as_supervised)
#     521         as_supervised=as_supervised,
#     522     )
# --> 523     datasets = utils.map_nested(build_single_dataset, split, map_tuple=True)
#     524     return datasets
#     525
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     178     if isinstance(data_struct, tuple(types)):
#     179       mapped = [map_nested(function, v, dict_only, map_tuple)
# --> 180                 for v in data_struct]
#     181       if isinstance(data_struct, list):
#     182         return mapped
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/utils/py_utils.py in <listcomp>(.0)
#     178     if isinstance(data_struct, tuple(types)):
#     179       mapped = [map_nested(function, v, dict_only, map_tuple)
# --> 180                 for v in data_struct]
#     181       if isinstance(data_struct, list):
#     182         return mapped
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     184         return tuple(mapped)
#     185   # Singleton
# --> 186   return function(data_struct)
#     187
#     188
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_builder.py in _build_single_dataset(self, split, shuffle_files, batch_size, decoders, read_config, as_supervised)
#     543         shuffle_files=shuffle_files,
#     544         decoders=decoders,
# --> 545         read_config=read_config,
#     546     )
#     547     # Auto-cache small datasets which are small enough to fit in memory.
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_builder.py in _as_dataset(self, split, decoders, read_config, shuffle_files)
#     965         split_infos=self.info.splits.values(),
#     966         read_config=read_config,
# --> 967         shuffle_files=shuffle_files,
#     968     )
#     969     decode_fn = functools.partial(
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/tfrecords_reader.py in read(self, name, instructions, split_infos, read_config, shuffle_files)
#     282       )
#     283
# --> 284     return tf.nest.map_structure(_read_instruction_to_ds, instructions)
#     285
#     286   def read_files(
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/tfrecords_reader.py in _read_instruction_to_ds(instruction)
#     279           file_instructions,
#     280           read_config=read_config,
# --> 281           shuffle_files=shuffle_files,
#     282       )
#     283
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/tfrecords_reader.py in read_files(self, file_instructions, read_config, shuffle_files)
#     316         read_config=read_config,
#     317         parse_fn=self._parser.parse_example,
# --> 318         shuffle_files=shuffle_files,
#     319     )
#     320     return ds
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/tfrecords_reader.py in _read_files(file_instructions, parse_fn, read_config, shuffle_files)
#     177   block_length = read_config.interleave_block_length
#     178
# --> 179   instruction_ds = tf.data.Dataset.from_tensor_slices(tensor_inputs)
#     180
#     181   # On distributed environement, we can shard per-file if a
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors)
#     680       Dataset: A `Dataset`.
#     681     """
# --> 682     return TensorSliceDataset(tensors)
#     683
#     684   class _GeneratorState(object):
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element)
#    2999   def __init__(self, element):
#    3000     """See `Dataset.from_tensor_slices()` for details."""
# -> 3001     element = structure.normalize_element(element)
#    3002     batched_spec = structure.type_spec_from_value(element)
#    3003     self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/data/util/structure.py in normalize_element(element)
#      96         # the value. As a fallback try converting the value to a tensor.
#      97         normalized_components.append(
# ---> 98             ops.convert_to_tensor(t, name="component_%d" % i))
#      99       else:
#     100         if isinstance(spec, sparse_tensor.SparseTensorSpec):
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     336                                          as_ref=False):
#     337   _ = as_ref
# --> 338   return constant(v, dtype=dtype, name=name)
#     339
#     340
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262   """
#     263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 264                         allow_broadcast=True)
#     265
#     266
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273       with trace.Trace("tf.constant"):
#     274         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     276
#     277   g = ops.get_default_graph()
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     298 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     299   """Implementation of eager constant."""
# --> 300   t = convert_to_eager_tensor(value, ctx, dtype)
#     301   if shape is None:
#     302     return t
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      95     except AttributeError:
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 97   ctx.ensure_initialized()
#      98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/context.py in ensure_initialized(self)
#     537         if self._use_tfrt is not None:
#     538           pywrap_tfe.TFE_ContextOptionsSetTfrt(opts, self._use_tfrt)
# --> 539         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     540       finally:
#     541         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# InternalError: CUDA runtime implicit initialization on GPU:0 failed. Status: out of memory

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'id': Text(shape=(), dtype=tf.string),
#     'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(50000, shape=(), dtype=int64)
# tf.Tensor(10000, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    # image = tf.image.resize(image, [32, 32])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_info.features["label"].num_classes
# Out:
# 10

# %%
ds_info.features["label"].names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
# function for building VGG Block

def build_vgg_block(input_layer,
                    num_cnn=3, 
                    channel=64,
                    block_num=1,
                   ):
    # 입력 레이어
    x = input_layer

    # CNN 레이어
    for cnn_num in range(num_cnn):
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(3,3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_conv{cnn_num}'
        )(x)    

    # Max Pooling 레이어
    x = keras.layers.MaxPooling2D(
        pool_size=(2, 2),
        strides=2,
        name=f'block{block_num}_pooling'
    )(x)

    return x

# %%
vgg_input_layer = keras.layers.Input(shape=(32,32,3))   # 입력 레이어 생성
vgg_block_output = build_vgg_block(vgg_input_layer)    # VGG 블록 생성

# %%
# 블록 1개짜리 model 생성
model = keras.Model(inputs=vgg_input_layer, outputs=vgg_block_output)  

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 16, 16, 64)        0
# =================================================================
# Total params: 75,648
# Trainable params: 75,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VGG 모델 자체를 생성하는 함수입니다.
def build_vgg(input_shape=(32,32,3),
              num_cnn_list=[2,2,3,3,3],
              channel_list=[64,128,256,512,512],
              num_classes=10):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer
    
    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_vgg_block(
            output,
            num_cnn=num_cnn, 
            channel=channel,
            block_num=i
        )
        
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(4096, activation='relu', name='fc1')(output)
    output = keras.layers.Dense(4096, activation='relu', name='fc2')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
# 기본값을 그대로 사용해서 VGG 모델을 만들면 VGG-16이 됩니다.
vgg_16 = build_vgg()

vgg_16.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 원하는 블록의 설계에 따라 매개변수로 리스트를 전달해 줍니다.
vgg_19 = build_vgg(
    num_cnn_list=[2,2,4,4,4],
    channel_list=[64,128,256,512,512]
)

vgg_19.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block0_conv0 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block0_conv1 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block0_pooling (MaxPooling2D (None, 16, 16, 64)        0
# _________________________________________________________________
# block1_conv0 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block1_pooling (MaxPooling2D (None, 8, 8, 128)         0
# _________________________________________________________________
# block2_conv0 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block2_pooling (MaxPooling2D (None, 4, 4, 256)         0
# _________________________________________________________________
# block3_conv0 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block3_pooling (MaxPooling2D (None, 2, 2, 512)         0
# _________________________________________________________________
# block4_conv0 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block4_pooling (MaxPooling2D (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 10)                40970
# =================================================================
# Total params: 38,947,914
# Trainable params: 38,947,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 256
EPOCH = 20

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
vgg_16.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_16 = vgg_16.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
#   2/195 [..............................] - ETA: 9s - loss: 2.3094 - accuracy: 0.0938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0273s vs `on_train_batch_end` time: 0.0683s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0273s vs `on_train_batch_end` time: 0.0683s). Check your callbacks.
# 195/195 [==============================] - 27s 139ms/step - loss: 2.1912 - accuracy: 0.1876 - val_loss: 2.0725 - val_accuracy: 0.2426
# Epoch 2/20
# 195/195 [==============================] - 21s 107ms/step - loss: 1.9966 - accuracy: 0.2768 - val_loss: 1.9569 - val_accuracy: 0.2705
# Epoch 3/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.8614 - accuracy: 0.3333 - val_loss: 1.8017 - val_accuracy: 0.3370
# Epoch 4/20
# 195/195 [==============================] - 17s 86ms/step - loss: 1.7436 - accuracy: 0.3751 - val_loss: 1.6748 - val_accuracy: 0.4056
# Epoch 5/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.6631 - accuracy: 0.4037 - val_loss: 1.6207 - val_accuracy: 0.4271
# Epoch 6/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.6046 - accuracy: 0.4228 - val_loss: 1.6301 - val_accuracy: 0.4210
# Epoch 7/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.5534 - accuracy: 0.4416 - val_loss: 1.5499 - val_accuracy: 0.4371
# Epoch 8/20
# 195/195 [==============================] - 17s 86ms/step - loss: 1.5047 - accuracy: 0.4615 - val_loss: 1.4739 - val_accuracy: 0.4638
# Epoch 9/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.4643 - accuracy: 0.4747 - val_loss: 1.4558 - val_accuracy: 0.4670
# Epoch 10/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.4234 - accuracy: 0.4906 - val_loss: 1.4407 - val_accuracy: 0.4858
# Epoch 11/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.3912 - accuracy: 0.5038 - val_loss: 1.4343 - val_accuracy: 0.5071
# Epoch 12/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.3541 - accuracy: 0.5164 - val_loss: 1.3532 - val_accuracy: 0.5286
# Epoch 13/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.3182 - accuracy: 0.5281 - val_loss: 1.3111 - val_accuracy: 0.5301
# Epoch 14/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.2817 - accuracy: 0.5418 - val_loss: 1.2961 - val_accuracy: 0.5329
# Epoch 15/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.2506 - accuracy: 0.5550 - val_loss: 1.2711 - val_accuracy: 0.5404
# Epoch 16/20
# 195/195 [==============================] - 17s 87ms/step - loss: 1.2180 - accuracy: 0.5671 - val_loss: 1.3054 - val_accuracy: 0.5366
# Epoch 17/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.1854 - accuracy: 0.5762 - val_loss: 1.2825 - val_accuracy: 0.5280
# Epoch 18/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.1605 - accuracy: 0.5875 - val_loss: 1.2792 - val_accuracy: 0.5438
# Epoch 19/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.1255 - accuracy: 0.6005 - val_loss: 1.1886 - val_accuracy: 0.5841
# Epoch 20/20
# 195/195 [==============================] - 17s 88ms/step - loss: 1.0988 - accuracy: 0.6099 - val_loss: 1.2039 - val_accuracy: 0.5759

# %%
vgg_19.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_19 = vgg_19.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/20
#   2/195 [..............................] - ETA: 19s - loss: 2.3028 - accuracy: 0.0996WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0348s vs `on_train_batch_end` time: 0.0825s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0348s vs `on_train_batch_end` time: 0.0825s). Check your callbacks.
# 195/195 [==============================] - 20s 105ms/step - loss: 2.2597 - accuracy: 0.1383 - val_loss: 2.2171 - val_accuracy: 0.1891
# Epoch 2/20
# 195/195 [==============================] - 20s 103ms/step - loss: 2.0870 - accuracy: 0.2307 - val_loss: 2.0051 - val_accuracy: 0.2856
# Epoch 3/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.9528 - accuracy: 0.2894 - val_loss: 1.8990 - val_accuracy: 0.3127
# Epoch 4/20
# 195/195 [==============================] - 20s 104ms/step - loss: 1.8242 - accuracy: 0.3405 - val_loss: 1.7484 - val_accuracy: 0.3634
# Epoch 5/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.7217 - accuracy: 0.3775 - val_loss: 1.6862 - val_accuracy: 0.3878
# Epoch 6/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.6558 - accuracy: 0.4001 - val_loss: 1.6516 - val_accuracy: 0.3970
# Epoch 7/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.5940 - accuracy: 0.4243 - val_loss: 1.5235 - val_accuracy: 0.4528
# Epoch 8/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.5376 - accuracy: 0.4450 - val_loss: 1.5375 - val_accuracy: 0.4449
# Epoch 9/20
# 195/195 [==============================] - 20s 104ms/step - loss: 1.4908 - accuracy: 0.4591 - val_loss: 1.4567 - val_accuracy: 0.4829
# Epoch 10/20
# 195/195 [==============================] - 20s 105ms/step - loss: 1.4449 - accuracy: 0.4781 - val_loss: 1.3840 - val_accuracy: 0.5069
# Epoch 11/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.4030 - accuracy: 0.4934 - val_loss: 1.4054 - val_accuracy: 0.4909
# Epoch 12/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.3627 - accuracy: 0.5100 - val_loss: 1.3406 - val_accuracy: 0.5132
# Epoch 13/20
# 195/195 [==============================] - 20s 104ms/step - loss: 1.3331 - accuracy: 0.5207 - val_loss: 1.3264 - val_accuracy: 0.5186
# Epoch 14/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.2873 - accuracy: 0.5386 - val_loss: 1.2838 - val_accuracy: 0.5471
# Epoch 15/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.2535 - accuracy: 0.5473 - val_loss: 1.2870 - val_accuracy: 0.5494
# Epoch 16/20
# 195/195 [==============================] - 20s 104ms/step - loss: 1.2265 - accuracy: 0.5603 - val_loss: 1.2221 - val_accuracy: 0.5678
# Epoch 17/20
# 195/195 [==============================] - 20s 104ms/step - loss: 1.1897 - accuracy: 0.5767 - val_loss: 1.2296 - val_accuracy: 0.5621
# Epoch 18/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.1500 - accuracy: 0.5882 - val_loss: 1.2614 - val_accuracy: 0.5562
# Epoch 19/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.1303 - accuracy: 0.5948 - val_loss: 1.1740 - val_accuracy: 0.5848
# Epoch 20/20
# 195/195 [==============================] - 20s 103ms/step - loss: 1.0909 - accuracy: 0.6091 - val_loss: 1.1688 - val_accuracy: 0.5839

# %%
import matplotlib.pyplot as plt

plt.plot(history_16.history['loss'], 'r')
plt.plot(history_19.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()

# %%
plt.plot(history_16.history['val_accuracy'], 'r')
plt.plot(history_19.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['vgg_16', 'vgg_19'], loc='upper left')
plt.show()
