# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### 기본블록

# %%
def build_resnet_block(input_layer ,num_cnn=2,stage_num=2, channel=64, is_50=False):
    
    x = input_layer
    short = x
  
    if not is_50:
        for cnn_num in range(num_cnn):
            if cnn_num == 0:
                if stage_num == 2:
                    stride = 1
                else:
                    stride = 2
                x = keras.layers.Conv2D(filters=channel, 
                                        kernel_size=(3, 3), 
                                        padding='same',
                                        strides=stride,
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn2')(x)
                
                
                short = keras.layers.Conv2D(filters=channel,
                                            kernel_size=(1, 1),
                                            strides=stride,
                                            padding='same',
                                            name=f'stage{stage_num}_{cnn_num+1}_short',
                                            )(short)
                short = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn3')(short)
                x = keras.layers.Add()([x, short])
                
                x = keras.layers.Activation('relu')(x)

                short = x
            else:
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn2')(x)

                x = keras.layers.Add()([x, short])

                x = keras.layers.Activation('relu')(x)

                short = x

    else:
        for cnn_num in range(num_cnn):
            if cnn_num == 0:
                
                if stage_num == 2:
                    stride = 1
                else:
                    stride = 2
                    
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(1, 1),
                                        strides = stride,
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stae{stage_num}_{cnn_num+1}_bn2')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel*4,
                                        kernel_size=(1, 1),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv3',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn3')(x)
                
             
                short = keras.layers.Conv2D(filters=channel*4,
                                            kernel_size=(1, 1),
                                            strides=stride,
                                            padding='same',
                                            name=f'stage{stage_num}_{cnn_num+1}_short',
                                            )(short)
                short = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn4')(short)
                x = keras.layers.Add()([x, short])
                x = keras.layers.Activation('relu')(x)
                
                short = x
            else:
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(1, 1),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stae{stage_num}_{cnn_num+1}_bn2')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel*4,
                                        kernel_size=(1, 1),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv3',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn3')(x)
                
                
                x = keras.layers.Add()([x, short])
                    
                x = keras.layers.Activation('relu')(x)
                
                short = x

                    
    return x

# %%
def build_resnet(input_shape=(32, 32, 3), is_50=False):
    
    num_cnn_ls = [3, 4, 6, 3]
    channel_ls = [64, 128, 256, 512]
    num_classes = 2
    
    
        
    input_layer = keras.layers.Input(shape=input_shape)

    x = input_layer
    x = keras.layers.Conv2D(filters = 64,
                            kernel_size=(7, 7),
                            strides=2,
                            kernel_initializer='he_normal',
                            padding='same',
                            name=f'conv2d_0',
                            )(x)

    x = keras.layers.BatchNormalization(name=f'batch_normalization_0')(x)
    x = keras.layers.Activation('relu', name=f'activation_0')(x)
    x = keras.layers.MaxPool2D(pool_size=(3,3), strides=2, padding='same', name=f'stage2_0_maxpooling')(x)
    
    output = x 
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_ls, channel_ls)):
        output = build_resnet_block(output,
                                    num_cnn=num_cnn,
                                    stage_num = i+2,
                                    channel=channel,
                                    is_50 = is_50,
                                    )

    output = keras.layers.AveragePooling2D(pool_size = 1,
                                           padding='same',
                                           name='avg_pool')(output)
    output = keras.layers.Flatten(name='flatten_6')(output)
    output = keras.layers.Dense(num_classes, activation='softmax',name='predictions')(output)

    model = keras.Model(inputs=input_layer, outputs=output)

    return model

# %% [markdown]
# ### ResNet-34, ResNet-50 Complete Model

# %%
resnet_34 = build_resnet(input_shape=(32, 32,3), is_50=False)
resnet_34.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_0 (Conv2D)               (None, 16, 16, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_0 (BatchNor (None, 16, 16, 64)   256         conv2d_0[0][0]
# __________________________________________________________________________________________________
# activation_0 (Activation)       (None, 16, 16, 64)   0           batch_normalization_0[0][0]
# __________________________________________________________________________________________________
# stage2_0_maxpooling (MaxPooling (None, 8, 8, 64)     0           activation_0[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv1 (Conv2D)         (None, 8, 8, 64)     36928       stage2_0_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8, 8, 64)     0           stage2_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2 (Conv2D)         (None, 8, 8, 64)     36928       activation[0][0]
# __________________________________________________________________________________________________
# stage2_1_short (Conv2D)         (None, 8, 8, 64)     4160        stage2_0_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn2 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn3 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_short[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 64)     0           stage2_1_bn2[0][0]
#                                                                  stage2_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 64)     0           add[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv1 (Conv2D)         (None, 8, 8, 64)     36928       activation_1[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 8, 64)     0           stage2_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2 (Conv2D)         (None, 8, 8, 64)     36928       activation_2[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn2 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_2_conv2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           stage2_2_bn2[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 8, 8, 64)     0           add_1[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv1 (Conv2D)         (None, 8, 8, 64)     36928       activation_3[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 64)     0           stage2_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2 (Conv2D)         (None, 8, 8, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn2 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_3_conv2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           stage2_3_bn2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 64)     0           add_2[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv1 (Conv2D)         (None, 4, 4, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 128)    0           stage3_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# stage3_1_short (Conv2D)         (None, 4, 4, 128)    8320        activation_5[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_short[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 128)    0           stage3_1_bn2[0][0]
#                                                                  stage3_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv1 (Conv2D)         (None, 4, 4, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 128)    0           stage3_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_2_conv2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 128)    0           stage3_2_bn2[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv1 (Conv2D)         (None, 4, 4, 128)    147584      activation_9[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 128)    0           stage3_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_10[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_3_conv2[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 128)    0           stage3_3_bn2[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv1 (Conv2D)         (None, 4, 4, 128)    147584      activation_11[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 128)    0           stage3_4_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_12[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_4_conv2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 128)    0           stage3_4_bn2[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 128)    0           add_6[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv1 (Conv2D)         (None, 2, 2, 256)    295168      activation_13[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 256)    0           stage4_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_14[0][0]
# __________________________________________________________________________________________________
# stage4_1_short (Conv2D)         (None, 2, 2, 256)    33024       activation_13[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_short[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 256)    0           stage4_1_bn2[0][0]
#                                                                  stage4_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv1 (Conv2D)         (None, 2, 2, 256)    590080      activation_15[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 256)    0           stage4_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_16[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_2_conv2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 256)    0           stage4_2_bn2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv1 (Conv2D)         (None, 2, 2, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2, 2, 256)    0           stage4_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_18[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_3_conv2[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 2, 2, 256)    0           stage4_3_bn2[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2, 2, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv1 (Conv2D)         (None, 2, 2, 256)    590080      activation_19[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 2, 2, 256)    0           stage4_4_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_20[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_4_conv2[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 2, 2, 256)    0           stage4_4_bn2[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2, 2, 256)    0           add_10[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv1 (Conv2D)         (None, 2, 2, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2, 2, 256)    0           stage4_5_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_5_conv2[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 2, 2, 256)    0           stage4_5_bn2[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 2, 2, 256)    0           add_11[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv1 (Conv2D)         (None, 2, 2, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_6_conv1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 256)    0           stage4_6_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_24[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_6_conv2[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 2, 2, 256)    0           stage4_6_bn2[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 2, 2, 256)    0           add_12[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv1 (Conv2D)         (None, 1, 1, 512)    1180160     activation_25[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 1, 1, 512)    0           stage5_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     activation_26[0][0]
# __________________________________________________________________________________________________
# stage5_1_short (Conv2D)         (None, 1, 1, 512)    131584      activation_25[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn3 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_short[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 1, 1, 512)    0           stage5_1_bn2[0][0]
#                                                                  stage5_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 1, 1, 512)    0           add_13[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     activation_27[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 1, 1, 512)    0           stage5_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_2_conv2[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 1, 1, 512)    0           stage5_2_bn2[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 1, 1, 512)    0           add_14[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv1 (Conv2D)         (None, 1, 1, 512)    2359808     activation_29[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 1, 1, 512)    0           stage5_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     activation_30[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_3_conv2[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 1, 1, 512)    0           stage5_3_bn2[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 1, 1, 512)    0           add_15[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 512)    0           activation_31[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 512)          0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 2)            1026        flatten_6[0][0]
# ==================================================================================================
# Total params: 21,315,650
# Trainable params: 21,298,498
# Non-trainable params: 17,152
# __________________________________________________________________________________________________

# %%
resnet_50 = build_resnet(is_50=True)
resnet_50.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_0 (Conv2D)               (None, 16, 16, 64)   9472        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_0 (BatchNor (None, 16, 16, 64)   256         conv2d_0[0][0]
# __________________________________________________________________________________________________
# activation_0 (Activation)       (None, 16, 16, 64)   0           batch_normalization_0[0][0]
# __________________________________________________________________________________________________
# stage2_0_maxpooling (MaxPooling (None, 8, 8, 64)     0           activation_0[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv1 (Conv2D)         (None, 8, 8, 64)     4160        stage2_0_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 64)     0           stage2_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2 (Conv2D)         (None, 8, 8, 64)     36928       activation_32[0][0]
# __________________________________________________________________________________________________
# stae2_1_bn2 (BatchNormalization (None, 8, 8, 64)     256         stage2_1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 64)     0           stae2_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv3 (Conv2D)         (None, 8, 8, 256)    16640       activation_33[0][0]
# __________________________________________________________________________________________________
# stage2_1_short (Conv2D)         (None, 8, 8, 256)    16640       stage2_0_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn3 (BatchNormalizatio (None, 8, 8, 256)    1024        stage2_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn4 (BatchNormalizatio (None, 8, 8, 256)    1024        stage2_1_short[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           stage2_1_bn3[0][0]
#                                                                  stage2_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 256)    0           add_16[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv1 (Conv2D)         (None, 8, 8, 64)     16448       activation_34[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 64)     0           stage2_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2 (Conv2D)         (None, 8, 8, 64)     36928       activation_35[0][0]
# __________________________________________________________________________________________________
# stae2_2_bn2 (BatchNormalization (None, 8, 8, 64)     256         stage2_2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 64)     0           stae2_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv3 (Conv2D)         (None, 8, 8, 256)    16640       activation_36[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn3 (BatchNormalizatio (None, 8, 8, 256)    1024        stage2_2_conv3[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           stage2_2_bn3[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 256)    0           add_17[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv1 (Conv2D)         (None, 8, 8, 64)     16448       activation_37[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 64)     0           stage2_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2 (Conv2D)         (None, 8, 8, 64)     36928       activation_38[0][0]
# __________________________________________________________________________________________________
# stae2_3_bn2 (BatchNormalization (None, 8, 8, 64)     256         stage2_3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 64)     0           stae2_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv3 (Conv2D)         (None, 8, 8, 256)    16640       activation_39[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn3 (BatchNormalizatio (None, 8, 8, 256)    1024        stage2_3_conv3[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           stage2_3_bn3[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 256)    0           add_18[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv1 (Conv2D)         (None, 4, 4, 128)    32896       activation_40[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 4, 128)    0           stage3_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_41[0][0]
# __________________________________________________________________________________________________
# stae3_1_bn2 (BatchNormalization (None, 4, 4, 128)    512         stage3_1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 4, 128)    0           stae3_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv3 (Conv2D)         (None, 4, 4, 512)    66048       activation_42[0][0]
# __________________________________________________________________________________________________
# stage3_1_short (Conv2D)         (None, 4, 4, 512)    131584      activation_40[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn3 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn4 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_1_short[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4, 4, 512)    0           stage3_1_bn3[0][0]
#                                                                  stage3_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 4, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv1 (Conv2D)         (None, 4, 4, 128)    65664       activation_43[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 128)    0           stage3_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_44[0][0]
# __________________________________________________________________________________________________
# stae3_2_bn2 (BatchNormalization (None, 4, 4, 128)    512         stage3_2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 4, 128)    0           stae3_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv3 (Conv2D)         (None, 4, 4, 512)    66048       activation_45[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn3 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_2_conv3[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 4, 4, 512)    0           stage3_2_bn3[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 4, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv1 (Conv2D)         (None, 4, 4, 128)    65664       activation_46[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 128)    0           stage3_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_47[0][0]
# __________________________________________________________________________________________________
# stae3_3_bn2 (BatchNormalization (None, 4, 4, 128)    512         stage3_3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 128)    0           stae3_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv3 (Conv2D)         (None, 4, 4, 512)    66048       activation_48[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn3 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_3_conv3[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4, 4, 512)    0           stage3_3_bn3[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 512)    0           add_21[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv1 (Conv2D)         (None, 4, 4, 128)    65664       activation_49[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 4, 4, 128)    0           stage3_4_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2 (Conv2D)         (None, 4, 4, 128)    147584      activation_50[0][0]
# __________________________________________________________________________________________________
# stae3_4_bn2 (BatchNormalization (None, 4, 4, 128)    512         stage3_4_conv2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 4, 4, 128)    0           stae3_4_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv3 (Conv2D)         (None, 4, 4, 512)    66048       activation_51[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn3 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_4_conv3[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 4, 4, 512)    0           stage3_4_bn3[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 4, 4, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv1 (Conv2D)         (None, 2, 2, 256)    131328      activation_52[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 2, 2, 256)    0           stage4_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_53[0][0]
# __________________________________________________________________________________________________
# stae4_1_bn2 (BatchNormalization (None, 2, 2, 256)    1024        stage4_1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 2, 2, 256)    0           stae4_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv3 (Conv2D)         (None, 2, 2, 1024)   263168      activation_54[0][0]
# __________________________________________________________________________________________________
# stage4_1_short (Conv2D)         (None, 2, 2, 1024)   525312      activation_52[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn4 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_1_short[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 2, 2, 1024)   0           stage4_1_bn3[0][0]
#                                                                  stage4_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 2, 2, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv1 (Conv2D)         (None, 2, 2, 256)    262400      activation_55[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 2, 2, 256)    0           stage4_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_56[0][0]
# __________________________________________________________________________________________________
# stae4_2_bn2 (BatchNormalization (None, 2, 2, 256)    1024        stage4_2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 2, 2, 256)    0           stae4_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv3 (Conv2D)         (None, 2, 2, 1024)   263168      activation_57[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_2_conv3[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 2, 2, 1024)   0           stage4_2_bn3[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 2, 2, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv1 (Conv2D)         (None, 2, 2, 256)    262400      activation_58[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 2, 2, 256)    0           stage4_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_59[0][0]
# __________________________________________________________________________________________________
# stae4_3_bn2 (BatchNormalization (None, 2, 2, 256)    1024        stage4_3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 2, 2, 256)    0           stae4_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv3 (Conv2D)         (None, 2, 2, 1024)   263168      activation_60[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_3_conv3[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 2, 2, 1024)   0           stage4_3_bn3[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 2, 2, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv1 (Conv2D)         (None, 2, 2, 256)    262400      activation_61[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 2, 2, 256)    0           stage4_4_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_62[0][0]
# __________________________________________________________________________________________________
# stae4_4_bn2 (BatchNormalization (None, 2, 2, 256)    1024        stage4_4_conv2[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 2, 2, 256)    0           stae4_4_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv3 (Conv2D)         (None, 2, 2, 1024)   263168      activation_63[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_4_conv3[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 2, 2, 1024)   0           stage4_4_bn3[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 2, 2, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv1 (Conv2D)         (None, 2, 2, 256)    262400      activation_64[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 2, 2, 256)    0           stage4_5_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_65[0][0]
# __________________________________________________________________________________________________
# stae4_5_bn2 (BatchNormalization (None, 2, 2, 256)    1024        stage4_5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 2, 2, 256)    0           stae4_5_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv3 (Conv2D)         (None, 2, 2, 1024)   263168      activation_66[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_5_conv3[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 2, 2, 1024)   0           stage4_5_bn3[0][0]
#                                                                  activation_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 2, 2, 1024)   0           add_27[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv1 (Conv2D)         (None, 2, 2, 256)    262400      activation_67[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_6_conv1[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 2, 2, 256)    0           stage4_6_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2 (Conv2D)         (None, 2, 2, 256)    590080      activation_68[0][0]
# __________________________________________________________________________________________________
# stae4_6_bn2 (BatchNormalization (None, 2, 2, 256)    1024        stage4_6_conv2[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 2, 2, 256)    0           stae4_6_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv3 (Conv2D)         (None, 2, 2, 1024)   263168      activation_69[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_6_conv3[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 2, 2, 1024)   0           stage4_6_bn3[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 2, 2, 1024)   0           add_28[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv1 (Conv2D)         (None, 1, 1, 512)    524800      activation_70[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 1, 1, 512)    0           stage5_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     activation_71[0][0]
# __________________________________________________________________________________________________
# stae5_1_bn2 (BatchNormalization (None, 1, 1, 512)    2048        stage5_1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 1, 1, 512)    0           stae5_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv3 (Conv2D)         (None, 1, 1, 2048)   1050624     activation_72[0][0]
# __________________________________________________________________________________________________
# stage5_1_short (Conv2D)         (None, 1, 1, 2048)   2099200     activation_70[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn3 (BatchNormalizatio (None, 1, 1, 2048)   8192        stage5_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn4 (BatchNormalizatio (None, 1, 1, 2048)   8192        stage5_1_short[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 1, 1, 2048)   0           stage5_1_bn3[0][0]
#                                                                  stage5_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 1, 1, 2048)   0           add_29[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv1 (Conv2D)         (None, 1, 1, 512)    1049088     activation_73[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 1, 1, 512)    0           stage5_2_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     activation_74[0][0]
# __________________________________________________________________________________________________
# stae5_2_bn2 (BatchNormalization (None, 1, 1, 512)    2048        stage5_2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 1, 1, 512)    0           stae5_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv3 (Conv2D)         (None, 1, 1, 2048)   1050624     activation_75[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn3 (BatchNormalizatio (None, 1, 1, 2048)   8192        stage5_2_conv3[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 1, 1, 2048)   0           stage5_2_bn3[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 1, 1, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv1 (Conv2D)         (None, 1, 1, 512)    1049088     activation_76[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 1, 1, 512)    0           stage5_3_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     activation_77[0][0]
# __________________________________________________________________________________________________
# stae5_3_bn2 (BatchNormalization (None, 1, 1, 512)    2048        stage5_3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 1, 1, 512)    0           stae5_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv3 (Conv2D)         (None, 1, 1, 2048)   1050624     activation_78[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn3 (BatchNormalizatio (None, 1, 1, 2048)   8192        stage5_3_conv3[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 1, 1, 2048)   0           stage5_3_bn3[0][0]
#                                                                  activation_76[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 1, 1, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_79[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 2)            4098        flatten_6[0][0]
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ### plainnet

# %%
def build_plainnet_block(input_layer ,num_cnn=2,stage_num=2, channel=64, is_50=False):
    
    x = input_layer
    short = x
  
    if not is_50:
        for cnn_num in range(num_cnn):
            if cnn_num == 0:
                if stage_num == 2:
                    stride = 1
                else:
                    stride = 2
                x = keras.layers.Conv2D(filters=channel, 
                                        kernel_size=(3, 3), 
                                        padding='same',
                                        strides=stride,
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn2')(x)
                
                
                x = keras.layers.Activation('relu')(x)

                short = x
            else:
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                        )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn2')(x)


                x = keras.layers.Activation('relu')(x)

                short = x

    else:
        for cnn_num in range(num_cnn):
            if cnn_num == 0:
                
                if stage_num == 2:
                    stride = 1
                else:
                    stride = 2
                    
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(1, 1),
                                        strides = stride,
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stae{stage_num}_{cnn_num+1}_bn2')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel*4,
                                        kernel_size=(1, 1),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv3',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn3')(x)
                
                x = keras.layers.Activation('relu')(x)
                
                short = x
            else:
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(1, 1),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv1',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn1')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel,
                                        kernel_size=(3, 3),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv2',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stae{stage_num}_{cnn_num+1}_bn2')(x)
                x = keras.layers.Activation('relu')(x)
                x = keras.layers.Conv2D(filters=channel*4,
                                        kernel_size=(1, 1),
                                        padding='same',
                                        name=f'stage{stage_num}_{cnn_num+1}_conv3',
                                       )(x)
                x = keras.layers.BatchNormalization(name=f'stage{stage_num}_{cnn_num+1}_bn3')(x)
                
                    
                x = keras.layers.Activation('relu')(x)
                
                short = x

                    
    return x

# %%
def build_plainnet(input_shape=(224, 224, 3), is_50=False):
    
    num_cnn_ls = [3, 4, 6, 3]
    channel_ls = [64, 128, 256, 512]
    num_classes = 2
    
    
        
    input_layer = keras.layers.Input(shape=input_shape)

    x = input_layer
    x = keras.layers.Conv2D(filters = 64,
                            kernel_size=(7, 7),
                            strides=2,
                            kernel_initializer='he_normal',
                            padding='same',
                            name=f'conv2d_0',
                            )(x)

    x = keras.layers.BatchNormalization(name=f'batch_normalization_0')(x)
    x = keras.layers.Activation('relu', name=f'activation_0')(x)
    x = keras.layers.MaxPool2D(pool_size=(3,3), strides=2, padding='same', name=f'stage2_0_maxpooling')(x)
    
    output = x 
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_ls, channel_ls)):
        output = build_plainnet_block(output,
                                    num_cnn=num_cnn,
                                    stage_num = i+2,
                                    channel=channel,
                                    is_50 = is_50,
                                    )

    output = keras.layers.AveragePooling2D(pool_size = 1,
                                           padding='same',
                                           name='avg_pool')(output)
    output = keras.layers.Flatten(name='flatten_6')(output)
    output = keras.layers.Dense(num_classes, activation='softmax',name='predictions')(output)

    model = keras.Model(inputs=input_layer, outputs=output)

    return model

# %% [markdown]
# ### ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34

# %% [markdown]
# ### 데이터  "cats_vs_dogs"

# %%
import urllib3
urllib3.disable_warnings()
splits = ['train[:80%]', 'train[80%:]']

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=list(splits),
    shuffle_files=True,
    with_info=True,
)

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    
    # 이미지의 크기가 달라 일정하게 resize
    image = tf.image.resize(image, (224, 224))
    
    return tf.cast(image, tf.float32)/255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    
    ds = ds.map(normalize_and_resize_img, num_parallel_calls=1)
    ds = ds.batch(batch_size)
    
    if not is_test:
        ds=ds.repeat()
        ds=ds.shuffle(200)
    
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
resnet_34 = build_resnet(input_shape=(224, 224, 3))
resnet_50 = build_resnet(is_50=True)

resnet_34_plain = build_plainnet(input_shape=(224, 224, 3))
resnet_50_plain = build_plainnet(is_50=True)

# %%
BATCH_SIZE =16
EPOCH = 10

# %%
ds_train, ds_info = tfds.load(
'cats_vs_dogs',
split='train[:80%]',
as_supervised=True,
    with_info=True,
)

ds_test, ds_info = tfds.load(
'cats_vs_dogs',
split='train[80%:]',
as_supervised=True,
    with_info=True,
)


ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test= apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9),
    metrics=['accuracy'],
)

history_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/10
#  985/1163 [========================>.....] - ETA: 14s - loss: 3.3865 - accuracy: 0.5121
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-21-2218aedc6950> in <module>
#      12     validation_data=ds_test,
#      13     verbose=1,
# ---> 14     use_multiprocessing=True,
#      15 )
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[16,256,14,14] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node functional_5/stage4_2_conv2/Conv2D (defined at <ipython-input-21-2218aedc6950>:14) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_31734]
#
# Function call stack:
# train_function

# %%
resnet_34_plain.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9),
    metrics=['accuracy'],
)

history_34_plain = resnet_34_plain.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %%
resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9),
    metrics=['accuracy'],
)

history_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %%
resnet_50_plain.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9),
    metrics=['accuracy'],
)

history_50_plain = resnet_50_plain.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)

# %%
import matplotlib.pyplot as plt

plt.plot(history_34.history['loss'], 'r')
plt.plot(history_34_plain.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'resnet_34_plain'], loc='upper left')
plt.show()

# %%
plt.plot(history_50.history['loss'], 'r')
plt.plot(history_50_plain.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'resnet_50_plain'], loc='upper left')
plt.show()
